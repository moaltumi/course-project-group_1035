# %%
import project_files as pf
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pf.load_and_process('../../data/raw/project files.csv')
df
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0       2015      1    1            4      AS             98            ANC
# 1       2015      1    1            4      AA           2336            LAX
# 2       2015      1    1            4      US            840            SFO
# 3       2015      1    1            4      AA            258            LAX
# 4       2015      1    1            4      AS            135            SEA
# ...      ...    ...  ...          ...     ...            ...            ...
# 469963  2015      1   31            6      B6            839            JFK
# 469964  2015      1   31            6      DL           1887            SEA
# 469965  2015      1   31            6      F9            300            DEN
# 469966  2015      1   31            6      F9            422            DEN
# 469967  2015      1   31            6      UA           1104            ANC
#
# ...

# %%
pf.correlmatrix(df)

# %% [markdown]
# ### **EVA question 1: Which flight numbers go the futhest distance?** ###
# **Average distance for each flight number

# %%
pf.scatterPlot(df,'FLIGHT_NUMBER','DISTANCE')

# %% [markdown]
# ### **EVA question 2: which days and airlines are most/least busy?** ###
# **Number of Flights on Different in Days of the Month**

# %%
pf.displot(df,'DAY','Number of days') #add bins=any numerical value, it shows the separation between the lines

# %% [markdown]
# There are consistently less flights on the weekends (largest difference on saturdays). Could be due to most buisness travel taking place between monday and friday which where much of the domestic travel takes place.

# %% [markdown]
# **Number of flights each airline has during the month of January**

# %%
# pf.displot(df.groupby(['AIRLINE','FLIGHT_NUMBER']),'AIRLINE','Airline distplot',bins=115) #use barplot for airline or scatter plot as it is a string value, diistplot works for numerical value

pf.countPlot(df,'AIRLINE')

# %% [markdown]
# Southwest airlines (WN) had the most flights during the month by a large margin with over 40000 more flights compared to the next highest Delta Airlines (DL). This is presumed to be because the southwest has a very large presence as a domestic carrier and offers cheap flights within the united states, while other airlines also compete to fly internationally as well as domestic.

# %% [markdown]
# ### **EVA question 3: Which airlines and days of the week are you most likely to be delayed** ###
# **Chances of being delayed with each airline based on probability**

# %%
pf.barplot(df,'AIRLINE','DELAYED_OR_NOT','Probability of airlines being delayed')#Probability of airlines being delayed, So MQ is most delayed

# %% [markdown]
# American eagle (MQ) and Frontier (F9) were most likely with a proability of being delayed close to 60%, with other airlines being under 50% of being delayed. Interestingly there seems to be *little* corrilation between number of flights and chances of being delayed, considering the airlines with the highest count of total flights proved to be delayed the least.

# %% [markdown]
# **Probabilty of being delayed on different days of the week**

# %%
pf.barplot(df,'DAY_OF_WEEK','DELAYED_OR_NOT','Probability of which day is being delayed most')#Probability of airlines being delayed

# %% [markdown]
# Chances of being delayed are close to 50% for both Sunday (7) and Monday (1).
