# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

project_files1 = pd.read_csv('data/raw/project files.csv')
#cleaned columns with NaN values
project_files1.drop(columns = ['DIVERTED', 'CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY','AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY','WEATHER_DELAY','Unnamed: 31'])
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# ...      ...    ...  ...          ...     ...            ...         ...
# 469963  2015      1   31            6      B6            839      N658JB
# 469964  2015      1   31            6      DL           1887      N855NW
# 469965  2015      1   31            6      F9            300      N218FR
# 469966  2015      1   31            6      F9            422      N954FR
# 469967  2015      1   31            6      UA           1104      N73251
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                 ANC                 SEA                    5  ...
# 1                 LAX                 PBI                   10  ...
# 2                 SFO                 CLT                   20  ...
# 3                 LAX                 MIA                   20  ...
# 4                 SEA                 ANC                   25  ...
# ...               ...                 ...                  ...  ...
# 469963            JFK                 BQN                 2359  ...
# 469964            SEA                 DTW                 2359  ...
# 469965            DEN                 TPA                 2359  ...
# 469966            DEN                 ATL                 2359  ...
# 469967            ANC                 DEN                 2359  ...
#
#         SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 0                  205         194.0     169.0      1448      404.0      4.0
# 1                  280         279.0     263.0      2330      737.0      4.0
# 2                  286         293.0     266.0      2296      800.0     11.0
# 3                  285         281.0     258.0      2342      748.0      8.0
# 4                  235         215.0     199.0      1448      254.0      5.0
# ...                ...           ...       ...       ...        ...      ...
# 469963             221         200.0     179.0      1576      416.0      3.0
# 469964             252         239.0     209.0      1927      644.0     14.0
# 469965             192         212.0     168.0      1506      525.0      9.0
# 469966             162         191.0     141.0      1199      500.0     10.0
# 469967             309         312.0     282.0      2405      703.0      7.0
#
#         SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DELAYED_OR_NOT
# 0                     430         408.0          -22.0           False
# 1                     750         741.0           -9.0           False
# 2                     806         811.0            5.0            True
# 3                     805         756.0           -9.0           False
# 4                     320         259.0          -21.0           False
# ...                   ...           ...            ...             ...
# 469963                440         419.0          -21.0           False
# 469964                711         658.0          -13.0           False
# 469965                511         534.0           23.0            True
# 469966                441         510.0           29.0            True
# 469967                708         710.0            2.0            True
#
# [469968 rows x 24 columns]

# %%
def load_and_process(url_or_path_to_csv_file):
    
    df = (pd.read_csv(url_or_path_to_csv_file)
          .drop(columns = ['DIVERTED','CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY','AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY','WEATHER_DELAY'])
          .dropna(axis = 1)
          .rename(columns = {"WHEELS_OFF" : "GATE_TO_TAKEOFF"}))
    return df

# %%
# def load_and_process(url_or_path_to_csv_file):
    
#     df = (pd.read_csv(url_or_path_to_csv_file)
#           .drop(columns = ['DIVERTED','CANCELLED', 'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY','AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY','WEATHER_DELAY'])
#           .rename(columns = {"WHEELS_OFF" : "GATE_TO_TAKEOFF"}))
#     return df

# %%
df=load_and_process('data/raw/project files.csv')
df
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0       2015      1    1            4      AS             98            ANC
# 1       2015      1    1            4      AA           2336            LAX
# 2       2015      1    1            4      US            840            SFO
# 3       2015      1    1            4      AA            258            LAX
# 4       2015      1    1            4      AS            135            SEA
# ...      ...    ...  ...          ...     ...            ...            ...
# 469963  2015      1   31            6      B6            839            JFK
# 469964  2015      1   31            6      DL           1887            SEA
# 469965  2015      1   31            6      F9            300            DEN
# 469966  2015      1   31            6      F9            422            DEN
# 469967  2015      1   31            6      UA           1104            ANC
#
#        DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  SCHEDULED_TIME  DISTANCE  \
# 0                      SEA                    5             205      1448
# 1                      PBI                   10             280      2330
# 2                      CLT                   20             286      2296
# 3                      MIA                   20             285      2342
# 4                      ANC                   25             235      1448
# ...                    ...                  ...             ...       ...
# 469963                 BQN                 2359             221      1576
# 469964                 DTW                 2359             252      1927
# 469965                 TPA                 2359             192      1506
# 469966                 ATL                 2359             162      1199
# 469967                 DEN                 2359             309      2405
#
#         SCHEDULED_ARRIVAL  DELAYED_OR_NOT
# 0                     430           False
# 1                     750           False
# 2                     806            True
# 3                     805           False
# 4                     320           False
# ...                   ...             ...
# 469963                440           False
# 469964                711           False
# 469965                511            True
# 469966                441            True
# 469967                708            True
#
# [469968 rows x 13 columns]

# %%
project_files2 = pd.read_csv('data/raw/project 2.csv')
project_files2
#no data needs to be cleaned for this data set
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
project_files3 = pd.read_csv('data/raw/project files 3.csv')
project_files3
#no data needs to be cleaned for this data set
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
# def barplot1(df):
#     sns.barplot(y = 'shots', x= 'won', data =df).set_title('Shots by winning/losing team')

# %%
# def barplot(df):
#     sns.barplot(y = count, x = 'DELAYED_OR_NOT', data =df).set_title('number of flights delayed versus on time')

# %%
# def displot(df):
#     sns.displot(df['DAY'], kde=False, bins=31).set_title('number of flights on days during the month')

# %%
# def displot2(df):
#     sns.displot(df['AIRLINE'], kde=False, bins=13).set_title('amount of flights per airline')

# %%
# def displot3(df):
#     sns.displot(df['ORIGIN_AIRPORT'], kde=False, bins=322).set_title('departing flights')

# %%
def correlmatrix(df):
    corr = df.corr()# plot the heatmap
    sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns,linewidths=0.5, vmin=0, vmax=1, annot=False, annot_kws={"size":8}, cmap=sns.diverging_palette(200, 20, as_cmap=True))

# %%
correlmatrix(df)

# %%
def scatterPlot(df,colx,coly): 
    df.plot(kind='scatter', x=colx, y=coly)

# %%
scatterPlot(df,'FLIGHT_NUMBER','ARRIVAL_DELAY')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ARRIVAL_DELAY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-dec8424a6c1e> in <module>
# ----> 1 scatterPlot(df,'FLIGHT_NUMBER','ARRIVAL_DELAY')
#
# <ipython-input-37-172f99b1096a> in scatterPlot(df, colx, coly)
#       1 def scatterPlot(df,colx,coly):
# ----> 2     df.plot(kind='scatter', x=colx, y=coly)
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     898         if kind in self._dataframe_kinds:
#     899             if isinstance(data, ABCDataFrame):
# --> 900                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     901             else:
#     902                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1041         scatter = ax.scatter(
#    1042             data[x].values,
# -> 1043             data[y].values,
#    1044             c=c_values,
#    1045             label=label,
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ARRIVAL_DELAY'

# %%
scatterPlot(df,'ARRIVAL_DELAY','FLIGHT_NUMBER')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ARRIVAL_DELAY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-fe4450a5f4c6> in <module>
# ----> 1 scatterPlot(df,'ARRIVAL_DELAY','FLIGHT_NUMBER')
#
# <ipython-input-45-172f99b1096a> in scatterPlot(df, colx, coly)
#       1 def scatterPlot(df,colx,coly):
# ----> 2     df.plot(kind='scatter', x=colx, y=coly)
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     898         if kind in self._dataframe_kinds:
#     899             if isinstance(data, ABCDataFrame):
# --> 900                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     901             else:
#     902                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~\miniconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1040             label = None
#    1041         scatter = ax.scatter(
# -> 1042             data[x].values,
#    1043             data[y].values,
#    1044             c=c_values,
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ARRIVAL_DELAY'

# %%
def displot(df,df_col,plot_title, bins):
    sns.distplot(df[df_col], kde=False, bins=bins).set_title(plot_title)

# %%
displot(df,'DAY','Number of days',31)
# Out:
# C:\Users\david\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def barplot(df,colx,coly,plot_title):
    sns.barplot(x = colx, y = coly, data = df).set_title(plot_title)

# %%
def displot(df,df_col,plot_title, bins):
    sns.distplot(df[df_col], kde=False, bins=bins).set_title(plot_title)

# %%
displot(df,'Airline',13)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3934ff3dbc5> in <module>
# ----> 1 displot(df,'Airline',13)
#
# NameError: name 'df' is not defined
